# %% [markdown]
# # Implementation of data augmentation

# %% [markdown]
# Data augmentation is used to create more datasets of variation when datasets is limited using different transformation which helps in reducing overfitting

# %%
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import load_img,img_to_array,array_to_img
import matplotlib.pyplot as plt

# %%
img = load_img(r"C:\Users\ASUS\Desktop\Ml_DL\code\Data_augmentation\cat.jpg", target_size=(200,200))

# %%
plt.imshow(img)

# %%
# Image augmentationg
datagen = ImageDataGenerator(
rotation_range=40,                         # for rotating
shear_range=0.2,                           # shearing
width_shift_range=0.2,                     # changing width elongating
height_shift_range=0.2,                    # more taller image
zoom_range=0.2,                            # zooming image
horizontal_flip=True,                      # flipping
fill_mode='nearest')

# %%
img = img_to_array(img)
img.shape
# Out:
# (200, 200, 3)

# %%
input_batch = img.reshape(1,200,200,3)                               # reshaping for extra number of image dimension

# %%
i = 0
for output in datagen.flow(input_batch,batch_size=1,save_to_dir='augmented'):
    i = i+1
    if i == 10:
        break

# %%
import os
from matplotlib.image import imread
folder_path = r"C:\Users\ASUS\Desktop\Ml_DL\code\Data_augmentation\augmented"
for image_filename in os.listdir(folder_path):
    image_path = os.path.join(folder_path, image_filename)
    print(image_path)
    image = imread(image_path)
    plt.imshow(image)
    plt.axis("off")
    plt.show()
# Out:
# C:\Users\ASUS\Desktop\Ml_DL\code\Data_augmentation\augmented\_0_2855.png
# C:\Users\ASUS\Desktop\Ml_DL\code\Data_augmentation\augmented\_0_3921.png
# C:\Users\ASUS\Desktop\Ml_DL\code\Data_augmentation\augmented\_0_5288.png
# C:\Users\ASUS\Desktop\Ml_DL\code\Data_augmentation\augmented\_0_7604.png
# C:\Users\ASUS\Desktop\Ml_DL\code\Data_augmentation\augmented\_0_7735.png
# C:\Users\ASUS\Desktop\Ml_DL\code\Data_augmentation\augmented\_0_7782.png
# C:\Users\ASUS\Desktop\Ml_DL\code\Data_augmentation\augmented\_0_8862.png
# C:\Users\ASUS\Desktop\Ml_DL\code\Data_augmentation\augmented\_0_8989.png
# C:\Users\ASUS\Desktop\Ml_DL\code\Data_augmentation\augmented\_0_936.png
# C:\Users\ASUS\Desktop\Ml_DL\code\Data_augmentation\augmented\_0_9974.png
